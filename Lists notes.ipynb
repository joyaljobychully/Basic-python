# %% [markdown]
# List is a datastructure in python.

# %% [markdown]
# #Lists are **MUTABLE**

# %% [markdown]
# ?1) What is the output of the following code block?
#
#
#
# > 1)
# ```
# my_list = [1,23,4]
# type(my_list)
# ```
#
#
# > 2)
#    ```
#    print(my_list)
#    ```
#
#
# > 3)
#   ```
#   my_list
#   ```

# %%
my_list = [1,23,4]
type(my_list)
# Out:
# list

# %%
print(my_list)
# Out:
# [1, 23, 4]

# %%
my_list
# Out:
# [1, 23, 4]

# %% [markdown]
# ?2) What is the output of the following:
#
#
# ```
# new_list = [5,'Jake',False,6.9]
# print(len(new_list))
# print(new_list[2])
# print(new_list[-1])
# print(new_list[1:9])
# print(new_list[1:1])
# print(new_list + ['kiki',True])
# ```

# %%
new_list = [5,'Jake',False,6.9]
print(len(new_list))
print(new_list[2])
print(new_list[-1])
print(new_list[1:9])
print(new_list[1:1])
print(new_list + ['kiki',True])
# Out:
# 4
# False
# 6.9
# ['Jake', False, 6.9]
# []
# [5, 'Jake', False, 6.9, 'kiki', True]

# %% [markdown]
# #**Lists follow indexing like strings and they can be sliced like strings**

# %% [markdown]
# ?3) What is the output of the following:
#
#
# ```
# new_list2 = ['a',2]
# new_list2*3
# ```

# %%
new_list2 = ['a',2]
new_list2*3
# Out:
# ['a', 2, 'a', 2, 'a', 2]

# %% [markdown]
# ?4)
# ```
# list_A = [2,4,6.2,23,-28,34,64,-234,-23,-235,-32]
# list_B = [2,5,'Ace']
# ```
#
#
# 1.   Find the smallest element in list_A
# 2.   Find the smallest element in list_B
# 3.   Find the largest element in list_A
# 4.   Find the largest element in list_B
# 5.   Find the sum of elements of list_A
# 6.   Sort list_A in ascending order
# 7.   Sort list_A in descending order

# %%
list_A = [2,4,6.2,23,-28,34,64,-234,-23,-235,-32]
list_B = [2,5,'Ace']

# %%
min(list_A)
# Out:
# -235

# %%
min(list_B)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-d9697c1e215b> in <module>()
# ----> 1 min(list_B)
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
max(list_A)
# Out:
# 64

# %%
max(list_B)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-8f06820828c0> in <module>()
# ----> 1 max(list_B)
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
sum(list_A)
# Out:
# -418.8

# %%
sorted(list_A)
# Out:
# [-235, -234, -32, -28, -23, 2, 4, 6.2, 23, 34, 64]

# %%
sorted(list_A,reverse=True)
# Out:
# [64, 34, 23, 6.2, 4, 2, -23, -28, -32, -234, -235]

# %% [markdown]
# ?5)
#
# ```
# a = [5,7,9]
# ```
#     1. Add element 15 at the end of the list
#     2. Add the list [10,12,19] at the end of the list to get a nested list

# %%
a = [5,7,9]

# %%
a.append(15)

# %%
a
# Out:
# [5, 7, 9, 15]

# %%
a.append([10,12,19])

# %%
a
# Out:
# [5, 7, 9, 15, [10, 12, 19]]

# %% [markdown]
# ?6)
#
# ```
# list_1 = ['Jack',16,False]
# list_2 = ['Jill',17,True]
# ```
# Merge the elements in both lists to form a new list with elements in list_1 coming first.

# %%
list_1 = ['Jack',16,False]
list_2 = ['Jill',17,True]
list_1.extend(list_2)
list_1
# Out:
# ['Jack', 16, False, 'Jill', 17, True]

# %% [markdown]
# ?7)
#
#
# ```
# list_1 = [1,3,4,5,8]
# ```
#     1. What is the output of list_1.pop()?
#     2. What is the output of list_1.pop(1)?
#     3. What is the output of list_1.remove(1)?

# %%
list_1 = [1,3,4,5,8]

# %%
list_1.pop()
# Out:
# 8

# %%
list_1.pop(1)
# Out:
# 3

# %%
list_1.remove(1)

# %% [markdown]
# ?8) What is the number of occurances of 7 in list [435,89,3939,3,8,1,5,3,7,234,23,7,9023,23,4,367,898,2,7,0,32,56]

# %%
a = [435,89,3939,3,8,1,5,3,7,234,23,7,9023,23,4,367,898,2,7,0,32,56]
a.count(7)
# Out:
# 3

# %% [markdown]
# ?9) What is the index of first occurance of 3 in [23,3,3,3,3,354,56,67,53,87]?

# %%
a=[23,3,3,3,3,354,56,67,53,87]
a.index(3)
# Out:
# 1

# %% [markdown]
# ?10) Sort the list  [435,89,3939,3,8,1,5,3,7,234,23,7,9023,23,4,367,898,2,7,0,32,56] in ascending and descending order using methods.

# %%
a = [435,89,3939,3,8,1,5,3,7,234,23,7,9023,23,4,367,898,2,7,0,32,56]
a.sort()
a
# Out:
# [0,
#  1,
#  2,
#  3,
#  3,
#  4,
#  5,
#  7,
#  7,
#  7,
#  8,
#  23,
#  23,
#  32,
#  56,
#  89,
#  234,
#  367,
#  435,
#  898,
#  3939,
#  9023]

# %%
a = [435,89,3939,3,8,1,5,3,7,234,23,7,9023,23,4,367,898,2,7,0,32,56]
a.sort(reverse=True)
a
# Out:
# [9023,
#  3939,
#  898,
#  435,
#  367,
#  234,
#  89,
#  56,
#  32,
#  23,
#  23,
#  8,
#  7,
#  7,
#  7,
#  5,
#  4,
#  3,
#  3,
#  2,
#  1,
#  0]

# %% [markdown]
# ?11) Reverse the list [435,89,3939,3,8,1,5,3,7,234,23,7,9023,23,4,367,898,2,7,0,32,56]

# %%
a = [435,89,3939,3,8,1,5,3,7,234,23,7,9023,23,4,367,898,2,7,0,32,56]
a.reverse()

# %%
a
# Out:
# [56,
#  32,
#  0,
#  7,
#  2,
#  898,
#  367,
#  4,
#  23,
#  9023,
#  7,
#  23,
#  234,
#  7,
#  3,
#  5,
#  1,
#  8,
#  3,
#  3939,
#  89,
#  435]

# %% [markdown]
# ?12)Sort the list [True,False] in ascending and descending order using methods.

# %%
a=[True,False]
a.sort()
a
# Out:
# [False, True]

# %%
a=[True,False]
a.sort(reverse=True)
a
# Out:
# [True, False]

# %% [markdown]
# ?13) In the list [1,3,4,5,6], insert 2 between 1 and 3

# %%
a = [1,3,4,5,6]

# %%
a.insert(1,2)

# %%
a
# Out:
# [1, 2, 3, 4, 5, 6]
