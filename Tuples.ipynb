# %% [markdown]
# ?1) Predict the output of the following code block:
#
#
# ```
# my_tuple = (1,'a',True)
# print(my_tuple)
# type(my_tuple)
# ```

# %%
my_tuple = (1,'a',True)
print(my_tuple)
print(type(my_tuple))
print(my_tuple[1])
# Out:
# (1, 'a', True)
# <class 'tuple'>
# a

# %% [markdown]
# ?2) Predict the output of the following code block:
#
#
# ```
# my_list = [1]
# print(type(my_list))
# my_tup1 = (1)
# print(type(my_tup1))
# my_tup2 = (1,)
# print(my_tup2)
#
# ```

# %%
my_list = [1]
print(type(my_list))
my_tup1 = (1)
print(type(my_tup1))
my_tup2 = (1,)
print(type(my_tup2))
# Out:
# <class 'list'>
# <class 'int'>
# <class 'tuple'>

# %% [markdown]
# ?3) Create an empty tuple

# %%
em_tup = ()
print(type(em_tup))
em_tup
# Out:
# <class 'tuple'>
# ()

# %% [markdown]
# #**Tuple slicing is similar to list slicing**

# %% [markdown]
# ?4) Sort the tuple (1,3,2)

# %%
sorted((1,3,2))
# Out:
# [1, 2, 3]

# %% [markdown]
# #**You get a list when you sort.**

# %% [markdown]
# ?5) Find the index of 23 in (48,12,34,63,234,65,883,23,34,828,66,28)

# %%
(48,12,34,63,234,65,883,23,34,828,66,28).index(23)
# Out:
# 7

# %% [markdown]
# #**No sorting coz tuples are immutable**

# %% [markdown]
# ?6) Find the number of occurances of 34 in (48,12,34,63,234,65,883,23,34,828,66,28)

# %%
(48,12,34,63,234,65,883,23,34,828,66,28).count(34)
# Out:
# 2

# %% [markdown]
# ?7) Predict the output of the following code block:
#
#
# ```
# tuple_1 = (1,5,3)
# tuple_1[1] = 0
# ```

# %%
tuple_1 = (1,5,3)
tuple_1[1] = 0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-f4faff4ca989> in <module>()
#       1 tuple_1 = (1,5,3)
# ----> 2 tuple_1[1] = 0
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# #**Tuples can't grow because of immutability**

# %% [markdown]
# ?8) Predict the output of the following code block:
#
#
# ```
# city_list = ['Delhi','Patna']
# river_list = ['Yamuna','Ganga']
# print(list(zip(city_list,river_list)))
# ```

# %%
city_list = ['Delhi','Patna']
river_list = ['Yamuna','Ganga']
print(list(zip(city_list,river_list)))
# Out:
# [('Delhi', 'Yamuna'), ('Patna', 'Ganga')]

# %% [markdown]
# ?9) Merge the tuples (1,2) and (3,4)

# %%
a = (1,2)
b = (3,4)
a+b
# Out:
# (1, 2, 3, 4)
