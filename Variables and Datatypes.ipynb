# %% [markdown]
# ##**Datatypes in Python**
#
#
# 1.   String(str)
# 2.   Boolean(bool)
#       *  True
#       *  False
# 3.   Numeric
#       *  integer(int)
#       *  float(float)
# 4.   Datetime

# %% [markdown]
# ?1) Demonstrate floor division

# %%
7//3
# Out:
# 2

# %% [markdown]
# ?2)Demonstrate modulus operation

# %%
7%3
# Out:
# 1

# %% [markdown]
# ?3)How do you express 4000000 in python?

# %%
4e6
# Out:
# 4000000.0

# %%
4E6
# Out:
# 4000000.0

# %% [markdown]
# 4)##**Predict the outputs** for a = 5 and b = 10
#
#
# 1.   a == b
# 2.   a != b
# 3.   a>b
# 4.   a<b
# 5.   a>=b
# 6.   a<=b
# 7.   2==2
# 8.   2==3

# %% [markdown]
# ?5) What is the output of the following?
#      a = 'algebra'
#
#
# 1.   a
# 2.   print(a)

# %%
a = 'algebra'

# %%
a
# Out:
# 'algebra'

# %%
print(a)
# Out:
# algebra

# %% [markdown]
# ?6)What is the output for print('A\nB')?

# %%
print('A\nB')
# Out:
# A
# B

# %% [markdown]
# ?7) How do you get the number of characters in sdfawouoasdhflashdf?

# %%
len('sdfawouoasdhflashdf')
# Out:
# 19

# %% [markdown]
# ?8) What is the output of 'abc'[-1]?

# %%
'abc'[-1]
# Out:
# 'c'

# %% [markdown]
# ##For the word KING, indices of K=**0/-4**, I=**1/-3**, N=**2/-2**, G=**3/-1**

# %% [markdown]
# ?9) What is the output of the following for wor = 'KINGLY'
#
#
# 1.   wor[1:4]
# 2.   wor[-4:-1]
# 3.   wor[:4]
# 4.   wor[::2]
# 5.   wor[::-1]
# 6.   wor[1:3:-1]
# 7.   wor[3:1:-1]
# 8.   wor[3:1]

# %% [markdown]
# ?10) How do you print the last 5 characters of word asldfiruofajsdlfalsdnvkahf by slicing?

# %%
chara = 'asldfiruofajsdlfalsdnvkahf'

# %%
chara[-5:]
# Out:
# 'vkahf'

# %% [markdown]
# ##Strings have the property of **IMMUTABILITY**

# %% [markdown]
# ?11) Assign the word King to me
#
#
# 1.   Return the word King with all the letters in lower case.
# 2.   Return the word King with all the letters in upper case.
# 3.   Find the number of occurances of 'n','N','ng', and '' in King.
# 4.   Find the index of 'n' in King
# 5.   Find the index of 'p' in King
# 6.   Change the word King to Kind

# %%
me = 'King'

# %%
me.lower()
# Out:
# 'king'

# %%
me.upper()
# Out:
# 'KING'

# %%
me.count('n')
# Out:
# 1

# %%
me.count('N')
# Out:
# 0

# %%
me.count('ng')
# Out:
# 1

# %%
me.count('')
# Out:
# 5

# %%
me.find('n')
# Out:
# 2

# %%
me.find('p')
# Out:
# -1

# %%
me.replace('g','d')
# Out:
# 'Kind'

# %% [markdown]
# ?12) What is the output of print(f'sdfasdf {me}')

# %%
print(f'sdfasdf {me}')
# Out:
# sdfasdf King

# %% [markdown]
# ?13) What is the output of 'me' in 'Hit me'?

# %%
'me' in 'Hit me'
# Out:
# True

# %% [markdown]
# ?14) What is the output of 'me'*10 in 'Hit me'?

# %%
'me'*10 in 'Hit me'
# Out:
# False

# %% [markdown]
# ?15)Let k = 'True'.
#
# > What is the datatype of k?

# %%
k='True'
type(k)
# Out:
# str

# %% [markdown]
# ?16) a, b = 17,18
#
#
#
# > What is the output of a + b?

# %%
a,b = 17,18
a+b
# Out:
# 35

# %%
a = 'werwd'
a.startswith('w')
# Out:
# True

# %% [markdown]
# ?17) Assign the string 'Asldkjflaieroiweodnfs,lasdfjo23jwdf Kudd' to check
#
#
#
# 1.   Check if all the characters are alphanumeric(nos and alphabets)?
# 2.   Check if all the characters are alphabets
# 3.   Check if all the characters are digits
# 4.   Check if all the words in string start with a capital letter.
# 5.   Check if all characters are lowercase
# 6.   Check if the string has only white spaces.
# 7.   Check if the string ends with p
# 8.   Check if the string starts with A.

# %%
check = 'Asldkjflaieroiweodnfs,lasdfjo23jwdf Kudd'

# %%
check.isalnum()
# Out:
# False

# %%
check.isalpha()
# Out:
# False

# %%
check.isdigit()
# Out:
# False

# %%
check.istitle()
# Out:
# False

# %%
check.islower()
# Out:
# False

# %%
check.isspace()
# Out:
# False

# %%
check.endswith('p')
# Out:
# False

# %%
check.startswith('A')
# Out:
# True
