# %% [markdown]
# ?1) Let a =['Stark','Targaryen']
#
#     1. Print the elements in reverse from list a=['Stark','Targaryen'] using for loop.
#     2. Print index and element pairs of a in a list
#     3. Print index and element pairs of a

# %%
a = ['Stark','Targaryen']
for house in a[::-1]:
  print(house)
# Out:
# Targaryen
# Stark

# %%
list(enumerate(a))
# Out:
# [(0, 'Stark'), (1, 'Targaryen')]

# %%
for ind,house in enumerate(a):
  print(ind,house)
# Out:
# 0 Stark
# 1 Targaryen

# %% [markdown]
# ?2) Create a list of nos from 10 to 15 in reverse.

# %%
list(range(15,9,-1))
# Out:
# [15, 14, 13, 12, 11, 10]

# %% [markdown]
# ?3) What is the ouput of following code block:
#
#
# ```
# word_list = ['King','How','You']
# for word in word_list:
#   if word not in ['I','You']:
#     print(word)
# ```

# %%
word_list = ['King','How','You']
for word in word_list:
  if word not in ['I','You']: # LIST used instead of using ors.
    print(word)
# Out:
# King
# How

# %% [markdown]
# ?4) What is the output of :
#
#
# ```
# country_city = [('India','New Delhi'),('England','London')]
# for country,city in country_city:
#   print(f'Capital of {country} is {city}')
# ```
# NB: TRY TO DO THIS BY YOURSELF

# %%
country_city = [('India','New Delhi'),('England','London')]
for country,city in country_city:
  print(f'Capital of {country} is {city}')
# Out:
# Capital of India is New Delhi
# Capital of England is London

# %% [markdown]
# ?5) What will be the output?
#
#
# ```
# country_city = [('India','New Delhi'),('England','London')]
# country_city_dict = dict(country_city)
# for item in country_city_dict:
#   print(item)
# for country,city in country_city_dict.items():
#   print(f'Capital of {country} is {city}')
# ```

# %%
country_city = [('India','New Delhi'),('England','London')]
country_city_dict = dict(country_city)
for item in country_city_dict:
  print(item)
for country,city in country_city_dict.items():
  print(f'Capital of {country} is {city}')
# Out:
# India
# England
# Capital of India is New Delhi
# Capital of England is London

# %% [markdown]
# ?6) Print the elements in {2,9,7} via iteration.

# %%
nos = {2,9,7}
for num in nos:
  print(num)
# Out:
# 9
# 2
# 7

# %% [markdown]
# *  **BREAK** - Breaks out of the current closest enclosing loop
# *   **CONTINUE**
# *   **PASS**

# %% [markdown]
# #while(0): runs 0 times.

# %% [markdown]
# #**Keywords in python cannot be used as variable names**
